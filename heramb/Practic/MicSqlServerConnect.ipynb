# %%
# !pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in E:\anaconda3\Lib\site-packages (5.3.0)

# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=LAPTOP-3RKKTDMH;"
    "DATABASE=Batch 16;"
    "Trusted_Connection=yes;"
    "TrustServerCertificate=yes;"
)

print("Connected successfully")

cursor = conn.cursor()
# Out:
# Connected successfully

# %%
cursor.execute("select * from employee")
cursor.fetchall()
# Out:
# [(1, 'Amit', datetime.datetime(2020, 1, 15, 9, 30), Decimal('35000.00')),
#  (2, 'Priya', None, Decimal('42000.00')),
#  (3, 'Rahul', datetime.datetime(2020, 7, 10, 8, 45), None),
#  (4, 'Sneha', datetime.datetime(2021, 2, 5, 11, 20), Decimal('50000.00')),
#  (5, 'Vikas', None, None),
#  (6, 'Neha', datetime.datetime(2021, 11, 25, 14, 0), Decimal('52000.00')),
#  (7, 'Arjun', datetime.datetime(2022, 1, 12, 10, 30), Decimal('45000.00')),
#  (8, 'Kiran', None, Decimal('55000.00')),
#  (9, 'Pooja', datetime.datetime(2022, 8, 17, 9, 0), None),
#  (10, 'Rohit', datetime.datetime(2022, 12, 1, 15, 20), Decimal('60000.00')),
#  (11, 'Anita', datetime.datetime(2023, 3, 14, 8, 30), Decimal('53000.00')),
#  (12, 'Deepak', None, Decimal('65000.00')),
#  (13, 'Meera', datetime.datetime(2023, 9, 9, 11, 45), Decimal('58000.00')),
#  (14, 'Sanjay', datetime.datetime(2023, 11, 28, 16, 0), None),
#  (15, 'Nisha', datetime.datetime(2024, 1, 16, 9, 25), Decimal('62000.00')),
#  (16, 'Ajay', datetime.datetime(2024, 4, 8, 10, 40), Decimal('75000.00')),
#  (17, 'Kavya', None, Decimal('68000.00')),
#  (18, 'Manoj', datetime.datetime(2024, 10, 3, 8, 50), Decimal('72000.00')),
#  (19, 'Riya', datetime.datetime(2025, 2, 11, 12, 0), None),
#  (20, 'Tarun', datetime.datetime(2025, 5, 27, 17, 10), Decimal('85000.00'))]

# %%
cursor.execute("""
SELECT COLUMN_NAME, DATA_TYPE, CHARACTER_MAXIMUM_LENGTH
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = 'employee'
""")

for row in cursor.fetchall():
    print(row)
# Out:
# ('EmpID', 'int', None)
# ('EmpName', 'varchar', 50)
# ('JoinDate', 'datetime', None)
# ('Salary', 'decimal', None)

# %%
cursor.execute("insert into employee (EmpID, EmpName, JoinDate, Salary) values (21, 'heramb','2020-01-15 09:30:00.000', 34000 )")

# %%
cursor.commit()
